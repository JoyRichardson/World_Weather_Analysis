# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 707

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | biltine
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | qorveh
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | sola
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | port hedland
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 1 | erenhot
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | longavi
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | vestmannaeyjar
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | itarema
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | amapa
# Processing Record 31 of Set 1 | kuytun
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | tabou
# Processing Record 34 of Set 1 | fortuna
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | san carlos de bariloche
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | mudyuga
# City not found. Skipping...
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | regina
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | ahipara
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | comodoro rivadavia
# Processing Record 2 of Set 2 | torata
# Processing Record 3 of Set 2 | rio gallegos
# Processing Record 4 of Set 2 | mahuva
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | ardersier
# City not found. Skipping...
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | nerchinskiy zavod
# Processing Record 9 of Set 2 | kununurra
# Processing Record 10 of Set 2 | sorland
# Processing Record 11 of Set 2 | nandyal
# Processing Record 12 of Set 2 | deputatskiy
# Processing Record 13 of Set 2 | uyemskiy
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | tubuala
# Processing Record 17 of Set 2 | port macquarie
# Processing Record 18 of Set 2 | hamilton
# Processing Record 19 of Set 2 | eureka
# Processing Record 20 of Set 2 | poyarkovo
# Processing Record 21 of Set 2 | helong
# Processing Record 22 of Set 2 | san fernando
# Processing Record 23 of Set 2 | hunchun
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | maposeni
# Processing Record 26 of Set 2 | vilhena
# Processing Record 27 of Set 2 | tignere
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | oranjemund
# Processing Record 30 of Set 2 | paracuru
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | valparaiso
# Processing Record 33 of Set 2 | yamasaki
# Processing Record 34 of Set 2 | nicoya
# Processing Record 35 of Set 2 | pyinmana
# Processing Record 36 of Set 2 | cartagena del chaira
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | bowen
# Processing Record 41 of Set 2 | paramonga
# Processing Record 42 of Set 2 | puerto leguizamo
# Processing Record 43 of Set 2 | quatre cocos
# Processing Record 44 of Set 2 | taltal
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | marau
# Processing Record 48 of Set 2 | porbandar
# Processing Record 49 of Set 2 | porto novo
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | caico
# Processing Record 6 of Set 3 | palmer
# Processing Record 7 of Set 3 | acapulco
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | farah
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | beloha
# Processing Record 12 of Set 3 | coquimbo
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | batemans bay
# Processing Record 15 of Set 3 | sisimiut
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | requena
# Processing Record 18 of Set 3 | maniitsoq
# Processing Record 19 of Set 3 | naze
# Processing Record 20 of Set 3 | dauphin
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | karasjok
# Processing Record 23 of Set 3 | zarubino
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | riyadh
# Processing Record 26 of Set 3 | kaohsiung
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | illora
# Processing Record 30 of Set 3 | dolores
# Processing Record 31 of Set 3 | tono
# Processing Record 32 of Set 3 | berlin
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | mocuba
# Processing Record 35 of Set 3 | shelburne
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | hami
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | marystown
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | bundaberg
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | inhambane
# Processing Record 46 of Set 3 | pietermaritzburg
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | nome
# Processing Record 49 of Set 3 | hokitika
# Processing Record 50 of Set 3 | sarangani
# Processing Record 1 of Set 4 | mataura
# Processing Record 2 of Set 4 | luanda
# Processing Record 3 of Set 4 | turbat
# Processing Record 4 of Set 4 | obo
# Processing Record 5 of Set 4 | lichtenburg
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | zhezkazgan
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | sao miguel do araguaia
# Processing Record 11 of Set 4 | codrington
# Processing Record 12 of Set 4 | moirang
# Processing Record 13 of Set 4 | ilhabela
# Processing Record 14 of Set 4 | bilma
# Processing Record 15 of Set 4 | yefira
# City not found. Skipping...
# Processing Record 16 of Set 4 | kamaishi
# Processing Record 17 of Set 4 | summerside
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | benjamin constant
# Processing Record 20 of Set 4 | sinnamary
# Processing Record 21 of Set 4 | mayor pablo lagerenza
# Processing Record 22 of Set 4 | boa vista
# Processing Record 23 of Set 4 | walvis bay
# Processing Record 24 of Set 4 | buala
# Processing Record 25 of Set 4 | arklow
# Processing Record 26 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 4 | moussoro
# Processing Record 28 of Set 4 | nelson bay
# Processing Record 29 of Set 4 | adrar
# Processing Record 30 of Set 4 | hopelchen
# Processing Record 31 of Set 4 | ulladulla
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | boyolangu
# Processing Record 36 of Set 4 | amot
# Processing Record 37 of Set 4 | voh
# Processing Record 38 of Set 4 | avarua
# Processing Record 39 of Set 4 | buchanan
# Processing Record 40 of Set 4 | talcahuano
# Processing Record 41 of Set 4 | carutapera
# Processing Record 42 of Set 4 | teya
# Processing Record 43 of Set 4 | tobol
# Processing Record 44 of Set 4 | kurtamysh
# Processing Record 45 of Set 4 | chicama
# Processing Record 46 of Set 4 | carstairs
# Processing Record 47 of Set 4 | jalu
# Processing Record 48 of Set 4 | manicore
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | vangaindrano
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | dakar
# Processing Record 3 of Set 5 | portobelo
# Processing Record 4 of Set 5 | bogovarovo
# Processing Record 5 of Set 5 | verkhniye tatyshly
# Processing Record 6 of Set 5 | tsalenjikha
# Processing Record 7 of Set 5 | puerto ayora
# Processing Record 8 of Set 5 | marsa matruh
# Processing Record 9 of Set 5 | stornoway
# Processing Record 10 of Set 5 | sur
# Processing Record 11 of Set 5 | iacobeni
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | hovd
# Processing Record 15 of Set 5 | divnogorsk
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | port lincoln
# Processing Record 18 of Set 5 | saint-joseph
# Processing Record 19 of Set 5 | makakilo city
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | college
# Processing Record 22 of Set 5 | curuguaty
# Processing Record 23 of Set 5 | macon
# Processing Record 24 of Set 5 | oksbol
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | astoria
# Processing Record 27 of Set 5 | garbolovo
# Processing Record 28 of Set 5 | marzuq
# Processing Record 29 of Set 5 | pandan
# Processing Record 30 of Set 5 | kilgore
# Processing Record 31 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 5 | komsomolskiy
# Processing Record 33 of Set 5 | mahon
# Processing Record 34 of Set 5 | guerrero negro
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | kabinda
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 5 | grand gaube
# Processing Record 41 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | ahvaz
# Processing Record 44 of Set 5 | worland
# Processing Record 45 of Set 5 | nhulunbuy
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | alta
# Processing Record 48 of Set 5 | vrangel
# Processing Record 49 of Set 5 | flinders
# Processing Record 50 of Set 5 | namibe
# Processing Record 1 of Set 6 | charters towers
# Processing Record 2 of Set 6 | bungu
# Processing Record 3 of Set 6 | cidreira
# Processing Record 4 of Set 6 | bud
# Processing Record 5 of Set 6 | raudeberg
# Processing Record 6 of Set 6 | antofagasta
# Processing Record 7 of Set 6 | kupang
# Processing Record 8 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 6 | port-gentil
# Processing Record 10 of Set 6 | clifton
# Processing Record 11 of Set 6 | mecca
# Processing Record 12 of Set 6 | aksu
# Processing Record 13 of Set 6 | paamiut
# Processing Record 14 of Set 6 | aksehir
# Processing Record 15 of Set 6 | kalemie
# Processing Record 16 of Set 6 | kieta
# Processing Record 17 of Set 6 | los llanos de aridane
# Processing Record 18 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | quelimane
# Processing Record 21 of Set 6 | santa maria
# Processing Record 22 of Set 6 | cockburn town
# Processing Record 23 of Set 6 | coihueco
# Processing Record 24 of Set 6 | yerbogachen
# Processing Record 25 of Set 6 | pakokku
# Processing Record 26 of Set 6 | kandrian
# Processing Record 27 of Set 6 | terekli-mekteb
# Processing Record 28 of Set 6 | tautira
# Processing Record 29 of Set 6 | gladstone
# Processing Record 30 of Set 6 | berdigestyakh
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | laguna
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | kathu
# Processing Record 38 of Set 6 | umm kaddadah
# Processing Record 39 of Set 6 | vardo
# Processing Record 40 of Set 6 | williston
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | roros
# Processing Record 43 of Set 6 | mehamn
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | dubbo
# Processing Record 46 of Set 6 | palm coast
# Processing Record 47 of Set 6 | kulhudhuffushi
# Processing Record 48 of Set 6 | hammond
# Processing Record 49 of Set 6 | husavik
# Processing Record 50 of Set 6 | pitimbu
# Processing Record 1 of Set 7 | havelock
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | kosh-agach
# Processing Record 4 of Set 7 | atasu
# Processing Record 5 of Set 7 | garowe
# Processing Record 6 of Set 7 | khandyga
# Processing Record 7 of Set 7 | acari
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | teguise
# Processing Record 11 of Set 7 | sabang
# Processing Record 12 of Set 7 | alihe
# Processing Record 13 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 7 | sibolga
# Processing Record 15 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 7 | hambantota
# Processing Record 17 of Set 7 | cervo
# Processing Record 18 of Set 7 | ferkessedougou
# Processing Record 19 of Set 7 | pacific grove
# Processing Record 20 of Set 7 | atar
# Processing Record 21 of Set 7 | caorle
# Processing Record 22 of Set 7 | tarakan
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | kindu
# Processing Record 25 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 7 | kahului
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | brigantine
# Processing Record 29 of Set 7 | mbanza-ngungu
# Processing Record 30 of Set 7 | vila franca do campo
# Processing Record 31 of Set 7 | beyneu
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | sangar
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | nioro
# Processing Record 38 of Set 7 | ust-ishim
# Processing Record 39 of Set 7 | cerrito
# Processing Record 40 of Set 7 | taybad
# Processing Record 41 of Set 7 | zhangjiakou
# Processing Record 42 of Set 7 | camopi
# Processing Record 43 of Set 7 | carauari
# Processing Record 44 of Set 7 | muroto
# Processing Record 45 of Set 7 | east london
# Processing Record 46 of Set 7 | iqaluit
# Processing Record 47 of Set 7 | high level
# Processing Record 48 of Set 7 | guanica
# Processing Record 49 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 50 of Set 7 | srikakulam
# Processing Record 1 of Set 8 | thinadhoo
# Processing Record 2 of Set 8 | mahmudabad
# Processing Record 3 of Set 8 | khurda
# Processing Record 4 of Set 8 | mandalgovi
# Processing Record 5 of Set 8 | namatanai
# Processing Record 6 of Set 8 | olinda
# Processing Record 7 of Set 8 | starobaltachevo
# Processing Record 8 of Set 8 | talnakh
# Processing Record 9 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 8 | cayenne
# Processing Record 11 of Set 8 | mirina
# City not found. Skipping...
# Processing Record 12 of Set 8 | tabas
# Processing Record 13 of Set 8 | aklavik
# Processing Record 14 of Set 8 | kembe
# Processing Record 15 of Set 8 | bom jesus
# Processing Record 16 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 8 | shingu
# Processing Record 18 of Set 8 | luderitz
# Processing Record 19 of Set 8 | lincoln
# Processing Record 20 of Set 8 | richards bay
# Processing Record 21 of Set 8 | mandera
# Processing Record 22 of Set 8 | prachuap khiri khan
# Processing Record 23 of Set 8 | carballo
# Processing Record 24 of Set 8 | natal
# Processing Record 25 of Set 8 | rapar
# Processing Record 26 of Set 8 | dunedin
# Processing Record 27 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | kokoda
# Processing Record 30 of Set 8 | bengkulu
# Processing Record 31 of Set 8 | salamiyah
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | bayir
# Processing Record 34 of Set 8 | zuenoula
# Processing Record 35 of Set 8 | swellendam
# Processing Record 36 of Set 8 | praia da vitoria
# Processing Record 37 of Set 8 | lakes entrance
# Processing Record 38 of Set 8 | honiara
# Processing Record 39 of Set 8 | ouadda
# Processing Record 40 of Set 8 | sulangan
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | rovaniemi
# Processing Record 46 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 8 | zyryanka
# Processing Record 48 of Set 8 | aswan
# Processing Record 49 of Set 8 | pemangkat
# Processing Record 50 of Set 8 | sayyan
# Processing Record 1 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 9 | the valley
# Processing Record 3 of Set 9 | karpathos
# Processing Record 4 of Set 9 | damghan
# Processing Record 5 of Set 9 | kachiry
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 9 | fukue
# Processing Record 9 of Set 9 | ribeira grande
# Processing Record 10 of Set 9 | san ramon
# Processing Record 11 of Set 9 | samarinda
# Processing Record 12 of Set 9 | odweyne
# Processing Record 13 of Set 9 | dubrovka
# Processing Record 14 of Set 9 | henties bay
# Processing Record 15 of Set 9 | kigoma
# Processing Record 16 of Set 9 | santiago del estero
# Processing Record 17 of Set 9 | nador
# Processing Record 18 of Set 9 | markala
# Processing Record 19 of Set 9 | loei
# Processing Record 20 of Set 9 | altamira
# Processing Record 21 of Set 9 | challans
# Processing Record 22 of Set 9 | jiran
# Processing Record 23 of Set 9 | montes claros
# Processing Record 24 of Set 9 | sandwick
# Processing Record 25 of Set 9 | fort nelson
# Processing Record 26 of Set 9 | galesong
# Processing Record 27 of Set 9 | bandarbeyla
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | hervey bay
# Processing Record 30 of Set 9 | tsabong
# Processing Record 31 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 9 | gurupi
# Processing Record 33 of Set 9 | ulety
# Processing Record 34 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 9 | doume
# Processing Record 36 of Set 9 | kemijarvi
# Processing Record 37 of Set 9 | yuci
# Processing Record 38 of Set 9 | emba
# Processing Record 39 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 9 | shimoda
# Processing Record 41 of Set 9 | batangafo
# Processing Record 42 of Set 9 | udachnyy
# Processing Record 43 of Set 9 | camabatela
# Processing Record 44 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | sabancuy
# Processing Record 47 of Set 9 | mindelo
# Processing Record 48 of Set 9 | dullewala
# Processing Record 49 of Set 9 | balkhash
# Processing Record 50 of Set 9 | grindavik
# Processing Record 1 of Set 10 | cherskiy
# Processing Record 2 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 10 | ternate
# Processing Record 4 of Set 10 | esso
# Processing Record 5 of Set 10 | darhan
# Processing Record 6 of Set 10 | bongaree
# Processing Record 7 of Set 10 | cody
# Processing Record 8 of Set 10 | airai
# Processing Record 9 of Set 10 | prince rupert
# Processing Record 10 of Set 10 | pascagoula
# Processing Record 11 of Set 10 | terney
# Processing Record 12 of Set 10 | svetlyy
# Processing Record 13 of Set 10 | tilichiki
# Processing Record 14 of Set 10 | kyra
# Processing Record 15 of Set 10 | ilabaya
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | zhicheng
# Processing Record 19 of Set 10 | timbiqui
# Processing Record 20 of Set 10 | samana
# Processing Record 21 of Set 10 | zhuanghe
# Processing Record 22 of Set 10 | kovdor
# Processing Record 23 of Set 10 | san jose
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | straumen
# Processing Record 26 of Set 10 | mayumba
# Processing Record 27 of Set 10 | tupi paulista
# Processing Record 28 of Set 10 | narsaq
# Processing Record 29 of Set 10 | general roca
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | yarmouth
# Processing Record 32 of Set 10 | nara
# Processing Record 33 of Set 10 | chai badan
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | ouesso
# Processing Record 36 of Set 10 | karratha
# Processing Record 37 of Set 10 | iberia
# Processing Record 38 of Set 10 | taoudenni
# Processing Record 39 of Set 10 | churapcha
# Processing Record 40 of Set 10 | waren
# Processing Record 41 of Set 10 | nargana
# Processing Record 42 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | takoradi
# Processing Record 44 of Set 10 | moose factory
# Processing Record 45 of Set 10 | goderich
# Processing Record 46 of Set 10 | isangel
# Processing Record 47 of Set 10 | hirara
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | stonewall
# Processing Record 50 of Set 10 | petrovskoye
# Processing Record 1 of Set 11 | araioses
# Processing Record 2 of Set 11 | katangli
# Processing Record 3 of Set 11 | nanortalik
# Processing Record 4 of Set 11 | milos
# Processing Record 5 of Set 11 | odienne
# Processing Record 6 of Set 11 | azrow
# City not found. Skipping...
# Processing Record 7 of Set 11 | mayo
# Processing Record 8 of Set 11 | tianpeng
# Processing Record 9 of Set 11 | meadow lake
# Processing Record 10 of Set 11 | talaya
# Processing Record 11 of Set 11 | tevaitoa
# Processing Record 12 of Set 11 | kochubey
# Processing Record 13 of Set 11 | tual
# Processing Record 14 of Set 11 | viedma
# Processing Record 15 of Set 11 | bang mun nak
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | sakaiminato
# Processing Record 18 of Set 11 | ust-omchug
# Processing Record 19 of Set 11 | kpandu
# Processing Record 20 of Set 11 | banda aceh
# Processing Record 21 of Set 11 | xining
# Processing Record 22 of Set 11 | kutum
# Processing Record 23 of Set 11 | wajir
# Processing Record 24 of Set 11 | stephenville
# Processing Record 25 of Set 11 | takapau
# Processing Record 26 of Set 11 | bolobo
# Processing Record 27 of Set 11 | balclutha
# Processing Record 28 of Set 11 | belem de sao francisco
# Processing Record 29 of Set 11 | kadaya
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | turuvekere
# Processing Record 32 of Set 11 | raga
# Processing Record 33 of Set 11 | galle
# Processing Record 34 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 11 | juneau
# Processing Record 36 of Set 11 | sambava
# Processing Record 37 of Set 11 | eydhafushi
# Processing Record 38 of Set 11 | dongning
# Processing Record 39 of Set 11 | bougouni
# Processing Record 40 of Set 11 | aksarka
# Processing Record 41 of Set 11 | ifanadiana
# Processing Record 42 of Set 11 | newport
# Processing Record 43 of Set 11 | tiruchchirappalli
# Processing Record 44 of Set 11 | xai-xai
# Processing Record 45 of Set 11 | kamenka
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | saint-francois
# Processing Record 48 of Set 11 | huallanca
# Processing Record 49 of Set 11 | gunjur
# Processing Record 50 of Set 11 | kenai
# Processing Record 1 of Set 12 | jiayuguan
# Processing Record 2 of Set 12 | vitim
# Processing Record 3 of Set 12 | okhotsk
# Processing Record 4 of Set 12 | willowmore
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 12 | bongandanga
# Processing Record 8 of Set 12 | trinidad
# Processing Record 9 of Set 12 | saint-pierre
# Processing Record 10 of Set 12 | ak-dovurak
# Processing Record 11 of Set 12 | auki
# Processing Record 12 of Set 12 | baykit
# Processing Record 13 of Set 12 | witu
# Processing Record 14 of Set 12 | christchurch
# Processing Record 15 of Set 12 | pedasi
# Processing Record 16 of Set 12 | poum
# Processing Record 17 of Set 12 | isla vista
# Processing Record 18 of Set 12 | aksaray
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | castrillon
# Processing Record 21 of Set 12 | panaba
# Processing Record 22 of Set 12 | pemba
# Processing Record 23 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 24 of Set 12 | muzhi
# Processing Record 25 of Set 12 | mareeba
# Processing Record 26 of Set 12 | brookings
# Processing Record 27 of Set 12 | aksha
# Processing Record 28 of Set 12 | temir
# Processing Record 29 of Set 12 | lakatoro
# Processing Record 30 of Set 12 | rio de janeiro
# Processing Record 31 of Set 12 | ilebo
# Processing Record 32 of Set 12 | suamico
# Processing Record 33 of Set 12 | san quintin
# Processing Record 34 of Set 12 | saquena
# Processing Record 35 of Set 12 | aanekoski
# Processing Record 36 of Set 12 | alta floresta
# Processing Record 37 of Set 12 | segezha
# Processing Record 38 of Set 12 | gonaives
# Processing Record 39 of Set 12 | dasoguz
# Processing Record 40 of Set 12 | craigieburn
# Processing Record 41 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 12 | grand-santi
# Processing Record 43 of Set 12 | santa fe
# Processing Record 44 of Set 12 | erzin
# Processing Record 45 of Set 12 | matagami
# Processing Record 46 of Set 12 | celestun
# Processing Record 47 of Set 12 | klaksvik
# Processing Record 48 of Set 12 | ayagoz
# Processing Record 49 of Set 12 | arroyo
# Processing Record 50 of Set 12 | pokhara
# Processing Record 1 of Set 13 | chifeng
# Processing Record 2 of Set 13 | sobolevo
# Processing Record 3 of Set 13 | manggar
# Processing Record 4 of Set 13 | broken hill
# Processing Record 5 of Set 13 | atamanovka
# Processing Record 6 of Set 13 | gossaigaon
# Processing Record 7 of Set 13 | kristiansund
# Processing Record 8 of Set 13 | tura
# Processing Record 9 of Set 13 | matara
# Processing Record 10 of Set 13 | bayangol
# Processing Record 11 of Set 13 | kant
# Processing Record 12 of Set 13 | northam
# Processing Record 13 of Set 13 | huayang
# Processing Record 14 of Set 13 | burgersdorp
# Processing Record 15 of Set 13 | vung tau
# Processing Record 16 of Set 13 | olymskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | santo antonio do ica
# Processing Record 18 of Set 13 | evensk
# Processing Record 19 of Set 13 | buin
# Processing Record 20 of Set 13 | benicarlo
# Processing Record 21 of Set 13 | biak
# Processing Record 22 of Set 13 | betong
# Processing Record 23 of Set 13 | charleston
# Processing Record 24 of Set 13 | tulun
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | belmonte
# Processing Record 27 of Set 13 | bolvasnita
# City not found. Skipping...
# Processing Record 28 of Set 13 | la peca
# Processing Record 29 of Set 13 | roblin
# Processing Record 30 of Set 13 | narayanavanam
# Processing Record 31 of Set 13 | arlit
# Processing Record 32 of Set 13 | puerto colombia
# Processing Record 33 of Set 13 | qasigiannguit
# Processing Record 34 of Set 13 | kloulklubed
# Processing Record 35 of Set 13 | morondava
# Processing Record 36 of Set 13 | forestville
# Processing Record 37 of Set 13 | alice springs
# Processing Record 38 of Set 13 | kokopo
# Processing Record 39 of Set 13 | skovorodino
# Processing Record 40 of Set 13 | breytovo
# Processing Record 41 of Set 13 | mao
# Processing Record 42 of Set 13 | maceio
# Processing Record 43 of Set 13 | manaure
# Processing Record 44 of Set 13 | kurchum
# Processing Record 45 of Set 13 | sri aman
# Processing Record 46 of Set 13 | hobyo
# Processing Record 47 of Set 13 | kota belud
# Processing Record 48 of Set 13 | kolo
# Processing Record 49 of Set 13 | aranos
# Processing Record 50 of Set 13 | massakory
# Processing Record 1 of Set 14 | santa rosa
# Processing Record 2 of Set 14 | dhidhdhoo
# Processing Record 3 of Set 14 | ulaangom
# Processing Record 4 of Set 14 | nakambala
# Processing Record 5 of Set 14 | muisne
# Processing Record 6 of Set 14 | yarim
# Processing Record 7 of Set 14 | plateros
# Processing Record 8 of Set 14 | krasnyy kholm
# Processing Record 9 of Set 14 | abu samrah
# Processing Record 10 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 11 of Set 14 | frolovo
# Processing Record 12 of Set 14 | bodden town
# Processing Record 13 of Set 14 | tazmalt
# Processing Record 14 of Set 14 | coahuayana
# Processing Record 15 of Set 14 | kapit
# Processing Record 16 of Set 14 | ishigaki
# Processing Record 17 of Set 14 | marrakesh
# Processing Record 18 of Set 14 | troitsko-pechorsk
# Processing Record 19 of Set 14 | bontang
# Processing Record 20 of Set 14 | guaruja
# Processing Record 21 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 14 | bonfim
# Processing Record 23 of Set 14 | loikaw
# Processing Record 24 of Set 14 | akropong
# Processing Record 25 of Set 14 | robertsport
# Processing Record 26 of Set 14 | wilmington
# Processing Record 27 of Set 14 | mercedes
# Processing Record 28 of Set 14 | uruzgan
# Processing Record 29 of Set 14 | cap malheureux
# Processing Record 30 of Set 14 | senador pompeu
# Processing Record 31 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 14 | havre-saint-pierre
# Processing Record 33 of Set 14 | alcudia
# Processing Record 34 of Set 14 | benghazi
# Processing Record 35 of Set 14 | port hardy
# Processing Record 36 of Set 14 | along
# Processing Record 37 of Set 14 | washougal
# Processing Record 38 of Set 14 | den helder
# Processing Record 39 of Set 14 | mana
# Processing Record 40 of Set 14 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 41 of Set 14 | puri
# Processing Record 42 of Set 14 | ozernovskiy
# Processing Record 43 of Set 14 | trelew
# Processing Record 44 of Set 14 | svetlogorsk
# Processing Record 45 of Set 14 | minbu
# Processing Record 46 of Set 14 | tadine
# Processing Record 47 of Set 14 | shasta lake
# Processing Record 48 of Set 14 | qaqortoq
# Processing Record 49 of Set 14 | gigmoto
# Processing Record 50 of Set 14 | saint anthony
# Processing Record 1 of Set 15 | ergani
# Processing Record 2 of Set 15 | shirokiy
# Processing Record 3 of Set 15 | apricena
# Processing Record 4 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 15 | khor
# Processing Record 6 of Set 15 | prieska
# Processing Record 7 of Set 15 | mizdah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 656

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Qaanaaq      GL  77.4840  -69.3632     40.05        75          83
# 1         Biltine      TD  14.5333   20.9167     79.02        68         100
# 2  Severo-Kurilsk      RU  50.6789  156.1250     57.92        89          89
# 3       Esperance      AU -33.8667  121.9000     53.44        76          90
# 4          Qorveh      IR  35.1664   47.8045     67.12        43           0
# 5          Castro      BR -24.7911  -50.0119     50.61        80           0
# 6           Kapaa      US  22.0752 -159.3190     84.18        83          90
# 7       Busselton      AU -33.6500  115.3333     57.04        71         100
# 8         Rikitea      PF -23.1203 -134.9692     70.25        58           9
# 9            Sola      VU -13.8833  167.5500     80.94        75          69
#
#    Wind Speed Current Description
# 0        2.24       broken clouds
# 1        2.64     overcast clouds
# 2        7.27     overcast clouds
# 3       20.65          light rain
# 4        1.25           clear sky
# 5        3.67           clear sky
# 6        1.99          light rain
# 7       14.00     overcast clouds
# 8       12.35           clear sky
# 9       17.54       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
